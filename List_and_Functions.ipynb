# %% [markdown]
# 7.4

# %%
things = ["mozzarella", "cinderella", "salmonella"]
things
# Out:
# ['mozzarella', 'cinderella', 'salmonella']

# %% [markdown]
# 7.5

# %%
things = ["mozzarella", "cinderella", "salmonella"]

things[1] = things[1].capitalize()

things
# Out:
# ['mozzarella', 'Cinderella', 'salmonella']

# %% [markdown]
# Yes it changed the element in the list from cinderella to Cinderella

# %% [markdown]
# 7.6

# %%
things = ["mozzarella", "Cinderella", "salmonella"]

things[0] = things[0].upper()

things
# Out:
# ['MOZZARELLA', 'Cinderella', 'salmonella']

# %% [markdown]
# 7.7

# %%
things = ["MOZZARELLA", "Cinderella", "salmonella"]

del things[2]

things
# Out:
# ['MOZZARELLA', 'Cinderella']

# %% [markdown]
# 9.1

# %%
def good():
    return ["Harry", "Ron", "Hermione"]

good()
# Out:
# ['Harry', 'Ron', 'Hermione']

# %% [markdown]
# 9.2

# %%
def get_odds():
    for number in range(10):
        if number % 2 == 1:
            yield number

count = 0

for number in get_odds():
    count += 1
    if count == 3:
        print(number)
        break
# Out:
# 5
